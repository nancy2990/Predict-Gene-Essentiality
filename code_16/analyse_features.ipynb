# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings("ignore")

# %%
ma = pd.read_csv("../16 Mycoplosma/ma.csv")
map = pd.read_csv("../16 Mycoplosma/map.csv")
marth = pd.read_csv("../16 Mycoplosma/marth.csv")
mcap = pd.read_csv("../16 Mycoplosma/mcap.csv")
mcon = pd.read_csv("../16 Mycoplosma/mcon.csv")
mcro = pd.read_csv("../16 Mycoplosma/mcro.csv")
mgal = pd.read_csv("../16 Mycoplosma/mgal.csv")
mhom = pd.read_csv("../16 Mycoplosma/mhom.csv")
mhyoJ = pd.read_csv("../16 Mycoplosma/mhyoJ.csv")
mhyo232 = pd.read_csv("../16 Mycoplosma/mhyo232.csv")
mhyo7448 = pd.read_csv("../16 Mycoplosma/mhyo7448.csv")
mm163K = pd.read_csv("../16 Mycoplosma/mm163K.csv")
mms = pd.read_csv("../16 Mycoplosma/mms.csv")
mpHF = pd.read_csv("../16 Mycoplosma/mpHF.csv")
mpM = pd.read_csv("../16 Mycoplosma/mpM.csv")
ms53 = pd.read_csv("../16 Mycoplosma/ms53.csv")

# %%
def calculate_essential(df):
    df['essentiality_0.6'] = (df['identity'] > 0.5).astype(int)
    df = df['essentiality_0.6'].value_counts().reset_index()
    df.columns = ['essentiality_0.6', 'count']
    print(df)

# %%
calculate_essential(ms53)
# Out:
#    essentiality_0.6  count
# 0                 0    202
# 1                 1    154

# %%
df1=pd.concat([ma, map,marth,mcap,mcon,mcro,mgal,mhom,mhyoJ,mhyo7448,mhyo232,mms,mm163K,mpM,mpHF,ms53], axis=0)

# %%
s1 = pd.read_csv("../../Staphylococcus/dataset/N315output.csv")
s2 = pd.read_csv("../../Staphylococcus/dataset/NCTCoutput.csv")
df3=pd.concat([s1,s2],axis=0)

# %%
df2 = pd.read_csv("../../E. coli/dataset/output.csv")

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
# Plotting each feature's values by essentiality in its own subplot
sns.boxplot(x='essentiality', y='GC_Content', data=df1, ax=axes[0])
axes[0].set_xticklabels(['Non-essential', 'Essential'])
axes[0].set_xlabel('Mycoplasma Gene Essentiality')
axes[0].set_ylabel('GC_Content')
axes[0].set_title('GC_Content by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essential', y='GC_Content', data=df2, ax=axes[1])
axes[1].set_xticklabels(['Non-essential', 'Essential'])
axes[1].set_xlabel('E. coli Gene Essentiality')
axes[1].set_ylabel('GC_Content')
axes[1].set_title('GC_Content by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='GC_Content', data=df3, ax=axes[2])
axes[2].set_xticklabels(['Non-essential', 'Essential'])
axes[2].set_xlabel('S. aureus Gene Essentiality')
axes[2].set_ylabel('GC_Content')
axes[2].set_title('GC_Content by Gene Essentiality for S. aureus')

plt.tight_layout()
plt.savefig("../GC_Content Distribution.png")
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
# Plotting each feature's values by essentiality in its own subplot
sns.boxplot(x='essentiality', y='CAI', data=df1, ax=axes[0])
axes[0].set_xticklabels(['Non-essential', 'Essential'])
axes[0].set_xlabel('Mycoplasma Gene Essentiality')
axes[0].set_ylabel('CAI')
axes[0].set_title('CAI by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essential', y='CAI', data=df2, ax=axes[1])
axes[1].set_xticklabels(['Non-essential', 'Essential'])
axes[1].set_xlabel('E. coli Gene Essentiality')
axes[1].set_ylabel('CAI')
axes[1].set_title('CAI by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='CAI', data=df3, ax=axes[2])
axes[2].set_xticklabels(['Non-essential', 'Essential'])
axes[2].set_xlabel('S. aureus Gene Essentiality')
axes[2].set_ylabel('CAI')
axes[2].set_title('CAI by Gene Essentiality for S. aureus')

plt.tight_layout()
plt.savefig("../CAI Distribution.png")
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# Plotting each feature's values by essentiality in its own subplot
sns.boxplot(x='essentiality', y='nSE2', data=df1, ax=axes[0][0])
axes[0][0].set_xticklabels(['Non-essential', 'Essential'])
axes[0][0].set_xlabel('Mycoplasma Gene Essentiality')
axes[0][0].set_ylabel('nSE2')
axes[0][0].set_title('nSE2 by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essentiality', y='nSE3', data=df1, ax=axes[0][1])
axes[0][1].set_xticklabels(['Non-essential', 'Essential'])
axes[0][1].set_xlabel('Mycoplasma Gene Essentiality')
axes[0][1].set_ylabel('nSE3')
axes[0][1].set_title('nSE3 by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essential', y='nSE2', data=df2, ax=axes[1][0])
axes[1][0].set_xticklabels(['Non-essential', 'Essential'])
axes[1][0].set_xlabel('E. coli Gene Essentiality')
axes[1][0].set_ylabel('nSE2')
axes[1][0].set_title('nSE2 by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='nSE3', data=df2, ax=axes[1][1])
axes[1][1].set_xticklabels(['Non-essential', 'Essential'])
axes[1][1].set_xlabel('E. coli Gene Essentiality')
axes[1][1].set_ylabel('nSE3')
axes[1][1].set_title('nSE3 by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='nSE2', data=df3, ax=axes[2][0])
axes[2][0].set_xticklabels(['Non-essential', 'Essential'])
axes[2][0].set_xlabel('S. aureus Gene Essentiality')
axes[2][0].set_ylabel('nSE2')
axes[2][0].set_title('nSE2 by Gene Essentiality for S. aureus')

sns.boxplot(x='essential', y='nSE3', data=df3, ax=axes[2][1])
axes[2][1].set_xticklabels(['Non-essential', 'Essential'])
axes[2][1].set_xlabel('S. aureus Gene Essentiality')
axes[2][1].set_ylabel('nSE3')
axes[2][1].set_title('nSE3 by Gene Essentiality for S. aureus')

plt.tight_layout()
plt.savefig("../SE Distribution.png")
plt.show()

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# Plotting each feature's values by essentiality in its own subplot
sns.boxplot(x='essentiality', y='nGE2', data=df1, ax=axes[0][0])
axes[0][0].set_xticklabels(['Non-essential', 'Essential'])
axes[0][0].set_xlabel('Mycoplasma Gene Essentiality')
axes[0][0].set_ylabel('nGE2')
axes[0][0].set_title('nGE2 by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essentiality', y='nGE3', data=df1, ax=axes[0][1])
axes[0][1].set_xticklabels(['Non-essential', 'Essential'])
axes[0][1].set_xlabel('Mycoplasma Gene Essentiality')
axes[0][1].set_ylabel('nGE3')
axes[0][1].set_title('nGE3 by Gene Essentiality for Mycoplasma')

sns.boxplot(x='essential', y='nGE2', data=df2, ax=axes[1][0])
axes[1][0].set_xticklabels(['Non-essential', 'Essential'])
axes[1][0].set_xlabel('E. coli Gene Essentiality')
axes[1][0].set_ylabel('nGE2')
axes[1][0].set_title('nGE2 by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='nGE3', data=df2, ax=axes[1][1])
axes[1][1].set_xticklabels(['Non-essential', 'Essential'])
axes[1][1].set_xlabel('E. coli Gene Essentiality')
axes[1][1].set_ylabel('nGE3')
axes[1][1].set_title('nGE3 by Gene Essentiality for E. coli')

sns.boxplot(x='essential', y='nGE2', data=df3, ax=axes[2][0])
axes[2][0].set_xticklabels(['Non-essential', 'Essential'])
axes[2][0].set_xlabel('S. aureus Gene Essentiality')
axes[2][0].set_ylabel('nGE2')
axes[2][0].set_title('nGE2 by Gene Essentiality for S. aureus')

sns.boxplot(x='essential', y='nGE3', data=df3, ax=axes[2][1])
axes[2][1].set_xticklabels(['Non-essential', 'Essential'])
axes[2][1].set_xlabel('S. aureus Gene Essentiality')
axes[2][1].set_ylabel('nGE3')
axes[2][1].set_title('nGE3 by Gene Essentiality for S. aureus')

plt.tight_layout()
plt.savefig("../GE Distribution.png")
plt.show()

# %%
amino_acid_cols = ['A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V']

sums_essential = df1[df1['essentiality'] == 1][amino_acid_cols].sum()/(df1['essentiality'] == 1).sum()
sums_nonessential = df1[df1['essentiality'] == 0][amino_acid_cols].sum()/(df1['essentiality'] == 0).sum()
sums_df = pd.DataFrame({'Essential': sums_essential, 'Non-Essential': sums_nonessential})
sums_df.plot.barh(figsize=(10, 8))
plt.xlabel('Amino Acid Frequency for Mycoplasma')
plt.title('Mycoplasma Amino Acid Frequency by Gene Essentiality')
plt.legend(title='Essentiality')
plt.tight_layout()
plt.savefig("../Mycoplasma Amino Acid.png")
plt.show()

# %%
sums_essential = df2[df2['essential'] == 1][amino_acid_cols].sum()/(df2['essential'] == 1).sum()
sums_nonessential = df2[df2['essential'] == 0][amino_acid_cols].sum()/(df2['essential'] == 0).sum()
sums_df = pd.DataFrame({'Essential': sums_essential, 'Non-Essential': sums_nonessential})
sums_df.plot.barh(figsize=(10, 8))
plt.xlabel('Amino Acid Frequency for E. coli')
plt.title('E. coli Amino Acid Frequency by Gene Essentiality')
plt.legend(title='Essentiality')
plt.tight_layout()
plt.savefig("../E. coli Amino Acid.png")
plt.show()

# %%
sums_essential = df3[df3['essential'] == 1][amino_acid_cols].sum()/(df3['essential'] == 1).sum()
sums_nonessential = df3[df3['essential'] == 0][amino_acid_cols].sum()/(df3['essential'] == 0).sum()
sums_df = pd.DataFrame({'Essential': sums_essential, 'Non-Essential': sums_nonessential})
sums_df.plot.barh(figsize=(10, 8))
plt.xlabel('Amino Acid Frequency for S. aureus')
plt.title('S. aureus Amino Acid Frequency by Gene Essentiality')
plt.legend(title='Essentiality')
plt.tight_layout()
plt.savefig("../S. aureus Amino Acid.png")
plt.show()
